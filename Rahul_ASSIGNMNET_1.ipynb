# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulpandeyrp/nlp/blob/main/Rahul_ASSIGNMNET_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ***What is the data type of each feature? (ordinal/nominal/interval/  ratio, discrete/continuous)***

# %% [markdown]
# 1.   longitude - Continous
# 2.   latitude - Continous
# 3.   housing_median_age -Continous
# 4.   total_rooms-Discrete
# 5.   total_bedrooms-discrete
# 6.   population-Discrete
# 7.   household-discrete
# 8.   median_income-continous
# 9.   median_house_value-continous
# 10.   ocean_proximity-Ordinal

# %% [markdown]
# **Q2.  Display summary statistics of the data. What can you learn from it on the data?**

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# *** From the describe method we can get mean,standard deviation.,Inter-Quartile Range,count of records etc.This gives us the idea of spread of the data***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# # info() gives us the metadata of dataframe.It includes informations like data type,non-null count etc.

# %% [markdown]
# **Q3. Compute the correlation between each feature and the target          median_house_value.Which features have strong correlation with the target?**

# %%
df.corrwith(df["median_house_value"])
# Out:
# longitude            -0.045967
# latitude             -0.144160
# housing_median_age    0.105623
# total_rooms           0.134153
# total_bedrooms        0.049686
# population           -0.024650
# households            0.065843
# median_income         0.688075
# median_house_value    1.000000
# dtype: float64

# %% [markdown]
# ## Correlation have value between [-1 to 1].Any feature having value at extremes of this range has strong relationship witht the target.
#
#  Median Income has strong correlation.Apart from that total rooms and latitude of a bit of correlation with target.

# %% [markdown]
# **Q4. Use data visualization tools to explore the data set. Display at least three different types of graphs.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
plt.hist(df['ocean_proximity'])

sns.countplot(x = "ocean_proximity",data=df)

# %%
sns.boxplot(y="median_income",data=df,color='blue')

# %%
plt.figure(figsize = (8,8))
plt.scatter(df['longitude'] , df['latitude'] , c = df['median_house_value'])
plt.colorbar()
plt.title("Housing Prices", size = 25)
plt.xlabel("longitude", size = 18)
plt.ylabel("latitude", size = 12);

# %% [markdown]
# **Q5 What type of problems can you detect in the data set? Name at least three different problems.**

# %% [markdown]
# # Problem 1: Total bedrooms have 207 null values

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# # Problem 2:Categorical data is not used for ML models

# %%
df["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# # Problem 3: outliers

# %%
sns.boxplot(y="median_income",data=df,color='blue')

# %% [markdown]
# **Q6.)Clean the data set using the data preprocessing techniques discussed in class. Show a sample of the data set before and after the cleaning.**

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df['total_bedrooms'].fillna(bedroom_median, inplace=True)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# **Problem 2 :Dealing with categorical variables**

# %%
dummies = pd.get_dummies(df.ocean_proximity)

# %%
df3 = pd.concat([df,dummies],axis='columns')

# %%
df3.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
# ...

# %% [markdown]
# **Q7. Extract at least two new features from the data set that have strong correlation with the target feature**

# %%
## Try to make some Feature Engineering --> Feature Extraction --> Add the new column to the main DF
df3['rooms_per_household'] = df3['total_rooms'] / df3['households']
df3['bedroms_per_rooms'] = df3['total_bedrooms'] / df3['total_rooms']
df3['population_per_household'] = df3['population'] / df3['households']

# %%
df3.corrwith(df["median_house_value"])
# Out:
# longitude                  -0.045967
# latitude                   -0.144160
# housing_median_age          0.105623
# total_rooms                 0.134153
# total_bedrooms              0.049457
# population                 -0.024650
# households                  0.065843
# median_income               0.688075
# median_house_value          1.000000
# <1H OCEAN                   0.256617
# INLAND                     -0.484859
# ISLAND                      0.023416
# NEAR BAY                    0.160284
# NEAR OCEAN                  0.141862
# rooms_per_household         0.151948
# bedroms_per_rooms          -0.233303
# population_per_household   -0.023737
# dtype: float64

# %% [markdown]
# ***bedroms_per_rooms and rooms_per_household have strong correlation***

# %% [markdown]
# # Q3

# %% [markdown]
# # 3.1

# %%
pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from apyori import apriori
import csv
with open('store_data.csv', newline='') as f:
    data = csv.reader(f)

# %%
#converting data into list format


store_data = list(data)

# %% [markdown]
# Converting into Dataframe using onehotencoding

# %%
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

encoder = TransactionEncoder()
encoder_fit = encoder.fit(store_data).transform(store_data)
store_data_2 = pd.DataFrame(encoder_fit, columns=encoder.columns_)
store_data_2
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %% [markdown]
# Using Apriori

# %%
freq_items = apriori(store_data_2, min_support=0.05, use_colnames=True)

len(freq_items)
# Out:
# 28

# %%
freq_items.sort_values(by=['support'], ascending = False, inplace=True)
freq_items
# Out:
#      support                    itemsets
# 16  0.238368             (mineral water)
# 6   0.179709                      (eggs)
# 21  0.174110                 (spaghetti)
# 8   0.170911              (french fries)
# 3   0.163845                 (chocolate)
# 12  0.132116                 (green tea)
# 15  0.129583                      (milk)
# 13  0.098254               (ground beef)
# 10  0.095321         (frozen vegetables)
# 18  0.095054                  (pancakes)
# 0   0.087188                   (burgers)
# 1   0.081056                      (cake)
# 4   0.080389                   (cookies)
# 7   0.079323                  (escalope)
# 14  0.076523            (low fat yogurt)
# 19  0.071457                    (shrimp)
# 22  0.068391                  (tomatoes)
# 17  0.065858                 (olive oil)
# 9   0.063325           (frozen smoothie)
# 23  0.062525                    (turkey)
# 2   0.059992                   (chicken)
# 27  0.059725  (spaghetti, mineral water)
# ...

# %% [markdown]
# ***Keeping metric as confidence***

# %%
rules_1 = association_rules(freq_items, metric="confidence", min_threshold=0.2)

# %%
rules.sort_values(by=['confidence','support'],ascending=False)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0      (spaghetti)  (mineral water)            0.174110            0.238368
# 2      (chocolate)  (mineral water)            0.163845            0.238368
# 4           (eggs)  (mineral water)            0.179709            0.238368
# 1  (mineral water)      (spaghetti)            0.238368            0.174110
# 3  (mineral water)      (chocolate)            0.238368            0.163845
# 5  (mineral water)           (eggs)            0.238368            0.179709
#
#     support  confidence      lift  leverage  conviction
# 0  0.059725    0.343032  1.439085  0.018223    1.159314
# 2  0.052660    0.321400  1.348332  0.013604    1.122357
# 4  0.050927    0.283383  1.188845  0.008090    1.062815
# 1  0.059725    0.250559  1.439085  0.018223    1.102008
# 3  0.052660    0.220917  1.348332  0.013604    1.073256
# 5  0.050927    0.213647  1.188845  0.008090    1.043158

# %% [markdown]
# ***Keeping metric as lift***

# %%
rules_1 = association_rules(freq_items, metric="lift", min_threshold=0.2)

# %%
rules.sort_values(by=['confidence','support'],ascending=False)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0      (spaghetti)  (mineral water)            0.174110            0.238368
# 2      (chocolate)  (mineral water)            0.163845            0.238368
# 4           (eggs)  (mineral water)            0.179709            0.238368
# 1  (mineral water)      (spaghetti)            0.238368            0.174110
# 3  (mineral water)      (chocolate)            0.238368            0.163845
# 5  (mineral water)           (eggs)            0.238368            0.179709
#
#     support  confidence      lift  leverage  conviction
# 0  0.059725    0.343032  1.439085  0.018223    1.159314
# 2  0.052660    0.321400  1.348332  0.013604    1.122357
# 4  0.050927    0.283383  1.188845  0.008090    1.062815
# 1  0.059725    0.250559  1.439085  0.018223    1.102008
# 3  0.052660    0.220917  1.348332  0.013604    1.073256
# 5  0.050927    0.213647  1.188845  0.008090    1.043158

# %% [markdown]
# # 2nd iteration with different parameters and thresholds

# %%
freq_items_2 = apriori(store_data_2, min_support=0.04, use_colnames=True)

len(freq_items_2)
# Out:
# 35

# %% [markdown]
# ***kept metric to lift***

# %%
rules_2= association_rules(freq_items_2, metric="lift", min_threshold=1)
rules_2.sort_values(by=['lift','confidence'],ascending=False)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 4  (mineral water)    (ground beef)            0.238368            0.098254
# 5    (ground beef)  (mineral water)            0.098254            0.238368
# 6           (milk)  (mineral water)            0.129583            0.238368
# 7  (mineral water)           (milk)            0.238368            0.129583
# 8      (spaghetti)  (mineral water)            0.174110            0.238368
# 9  (mineral water)      (spaghetti)            0.238368            0.174110
# 0      (chocolate)  (mineral water)            0.163845            0.238368
# 1  (mineral water)      (chocolate)            0.238368            0.163845
# 2           (eggs)  (mineral water)            0.179709            0.238368
# 3  (mineral water)           (eggs)            0.238368            0.179709
#
#     support  confidence      lift  leverage  conviction
# 4  0.040928    0.171700  1.747522  0.017507    1.088672
# ...

# %% [markdown]
# # Kept metric to support

# %%
rules_2 = association_rules(freq_items_2, metric="support", min_threshold=0.02)
rules_2.sort_values(by=['support','confidence'],ascending=False)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 8      (spaghetti)  (mineral water)            0.174110            0.238368
# 9  (mineral water)      (spaghetti)            0.238368            0.174110
# 0      (chocolate)  (mineral water)            0.163845            0.238368
# 1  (mineral water)      (chocolate)            0.238368            0.163845
# 2           (eggs)  (mineral water)            0.179709            0.238368
# 3  (mineral water)           (eggs)            0.238368            0.179709
# 6           (milk)  (mineral water)            0.129583            0.238368
# 7  (mineral water)           (milk)            0.238368            0.129583
# 5    (ground beef)  (mineral water)            0.098254            0.238368
# 4  (mineral water)    (ground beef)            0.238368            0.098254
#
#     support  confidence      lift  leverage  conviction
# 8  0.059725    0.343032  1.439085  0.018223    1.159314
# ...

# %% [markdown]
# #  3.2 Display the top scoring rules and discuss their meaning.

# %%
freq_items = apriori(store_data_2, min_support=0.05, use_colnames=True)



rules_1 = association_rules(freq_items, metric="confidence", min_threshold=0.2)
rules_1.sort_values(by=['confidence'],ascending=False)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 4      (spaghetti)  (mineral water)            0.174110            0.238368
# 0      (chocolate)  (mineral water)            0.163845            0.238368
# 2           (eggs)  (mineral water)            0.179709            0.238368
# 5  (mineral water)      (spaghetti)            0.238368            0.174110
# 1  (mineral water)      (chocolate)            0.238368            0.163845
# 3  (mineral water)           (eggs)            0.238368            0.179709
#
#     support  confidence      lift  leverage  conviction
# 4  0.059725    0.343032  1.439085  0.018223    1.159314
# 0  0.052660    0.321400  1.348332  0.013604    1.122357
# 2  0.050927    0.283383  1.188845  0.008090    1.062815
# 5  0.059725    0.250559  1.439085  0.018223    1.102008
# 1  0.052660    0.220917  1.348332  0.013604    1.073256
# 3  0.050927    0.213647  1.188845  0.008090    1.043158

# %% [markdown]
# As we have sorted our data according confidence we can say that ⁉
#
# Spaghetti-->mineral water
#
#  Above relation has top score.It makes sense because people may feel thirsty after eating spaghetti as it has rich ingredients present in it.
#
#  eggs-->mineral water
#
#
# Above relation also has good score.It makes sense because people who buy mineral water are health conscious and hence they buy mineral water as well.

# %% [markdown]
# # 3.3

# %%
import random
with open('store_data.csv', newline='') as f:
    reader = csv.reader(f)
    data_new = list(reader)

data_1 = random.sample(data, len(data) // 1)

encoder_fit_new = encoder.fit(data_new).transform(data_new)
store_data_3 = pd.DataFrame(encoder_fit_new, columns=encoder.columns_)

store_data_3
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
df_1 = store_data_3.iloc[:3700,:]
df_2 = store_data_3.iloc[3700:,:]
print("Shape of new dataframes - {} , {}".format(df_1.shape, df_2.shape))
# Out:
# Shape of new dataframes - (3700, 120) , (3801, 120)

# %%
freq_items_3 = apriori(df_1, min_support=0.05, use_colnames=True)

len(freq_items_3)
# Out:
# 29

# %%
rules_3 = association_rules(freq_items_3, metric="confidence", min_threshold=0.1)
rules_3.sort_values(by=['confidence'],ascending=False)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 4           (milk)  (mineral water)            0.132973            0.238378
# 6      (spaghetti)  (mineral water)            0.181081            0.238378
# 0      (chocolate)  (mineral water)            0.175135            0.238378
# 2           (eggs)  (mineral water)            0.188649            0.238378
# 7  (mineral water)      (spaghetti)            0.238378            0.181081
# 1  (mineral water)      (chocolate)            0.238378            0.175135
# 3  (mineral water)           (eggs)            0.238378            0.188649
# 5  (mineral water)           (milk)            0.238378            0.132973
#
#     support  confidence      lift  leverage  conviction
# 4  0.052432    0.394309  1.654130  0.020735    1.257442
# 6  0.060541    0.334328  1.402511  0.017375    1.144140
# 0  0.055946    0.319444  1.340073  0.014198    1.119117
# 2  0.052973    0.280802  1.177969  0.008003    1.058988
# ...

# %%
freq_items_4 = apriori(df_2, min_support=0.05, use_colnames=True)

len(freq_items_4)
# Out:
# 25

# %%
rules_4 = association_rules(freq_items_4, metric="confidence", min_threshold=0.1)
rules_4.sort_values(by=['confidence'],ascending=False)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0      (spaghetti)  (mineral water)            0.167324            0.238358
# 1  (mineral water)      (spaghetti)            0.238358            0.167324
#
#     support  confidence      lift  leverage  conviction
# 0  0.058932    0.352201  1.477613  0.019049    1.175738
# 1  0.058932    0.247241  1.477613  0.019049    1.106164

# %% [markdown]
# ***1.) We can see that for both the set of data set have same rules i.e    {spaghetti}-->{mineral water} & {mineral water}-->{spaghetti}***
#
# ***2.)Second set has less number of associations and rules eventhough both the data set has almost same number of data(2nd set has more)***
